# %%
import numpy as np
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt
import math
import tensorflow
import keras
# Out:
# Using TensorFlow backend.

# %%
# Create a random dataset
rng = np.random.RandomState(1)
#X = np.sort(5 * rng.rand(80, 1), axis=0)
#setup ndarray of x points and no y points 
X = np.arange(-10, 10.0, 1)[:, np.newaxis]
#y = np.sin(X).ravel()
y =  X**3

#y[::5] += 3 * (0.5 - rng.rand(16))

# %%
# Fit regression model
regr_1 = DecisionTreeRegressor(max_depth=2)
regr_2 = DecisionTreeRegressor(max_depth=5)
regr_1.fit(X, y)
regr_2.fit(X, y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=5, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
# Predict
X_test = np.arange(-10, 10.0, 1)[:, np.newaxis]
y_1 = regr_1.predict(X_test)
a = np.hstack(y_1)
print(a.shape)
print(y_1.shape)

y_2 = regr_2.predict(X_test)
# Out:
# (20,)
# (20,)

# %%
# show the decision tree
from sklearn import tree

#tree.export_graphviz(regr_1,"mytree.dot")
tree.plot_tree(regr_1,filled=True,rounded=True)
# Out:
# [Text(167.4, 181.2, 'X[0] <= -6.5\nmse = 145340.5\nsamples = 20\nvalue = -50.0'),
#  Text(83.7, 108.72, 'X[0] <= -8.5\nmse = 60492.5\nsamples = 4\nvalue = -646.0'),
#  Text(41.85, 36.23999999999998, 'mse = 18360.25\nsamples = 2\nvalue = -864.5'),
#  Text(125.55000000000001, 36.23999999999998, 'mse = 7140.25\nsamples = 2\nvalue = -427.5'),
#  Text(251.10000000000002, 108.72, 'X[0] <= 6.5\nmse = 55547.5\nsamples = 16\nvalue = 99.0'),
#  Text(209.25, 36.23999999999998, 'mse = 10334.0\nsamples = 13\nvalue = 0.0'),
#  Text(292.95, 36.23999999999998, 'mse = 24960.667\nsamples = 3\nvalue = 528.0')]

# %%
tree.plot_tree(regr_2,filled=True,rounded=True)
# Out:
# [Text(148.21875, 199.32, 'X[0] <= -6.5\nmse = 145340.5\nsamples = 20\nvalue = -50.0'),
#  Text(55.800000000000004, 163.07999999999998, 'X[0] <= -8.5\nmse = 60492.5\nsamples = 4\nvalue = -646.0'),
#  Text(27.900000000000002, 126.83999999999999, 'X[0] <= -9.5\nmse = 18360.25\nsamples = 2\nvalue = -864.5'),
#  Text(13.950000000000001, 90.6, 'mse = 0.0\nsamples = 1\nvalue = -1000.0'),
#  Text(41.85, 90.6, 'mse = 0.0\nsamples = 1\nvalue = -729.0'),
#  Text(83.7, 126.83999999999999, 'X[0] <= -7.5\nmse = 7140.25\nsamples = 2\nvalue = -427.5'),
#  Text(69.75, 90.6, 'mse = 0.0\nsamples = 1\nvalue = -512.0'),
#  Text(97.65, 90.6, 'mse = 0.0\nsamples = 1\nvalue = -343.0'),
#  Text(240.63750000000002, 163.07999999999998, 'X[0] <= 6.5\nmse = 55547.5\nsamples = 16\nvalue = 99.0'),
#  Text(174.375, 126.83999999999999, 'X[0] <= -3.5\nmse = 10334.0\nsamples = 13\nvalue = 0.0'),
#  Text(125.55000000000001, 90.6, 'X[0] <= -5.5\nmse = 3900.667\nsamples = 3\nvalue = -135.0'),
# ...

# %%
# Plot the results
from matplotlib.pyplot import figure
plt.figure(num=None, figsize=(12, 4), dpi=100, facecolor='w', edgecolor='k')
plt.scatter(X, y, s=20, edgecolor="black",
            c="darkorange", label="data")
plt.plot(X_test, y_1, color="cornflowerblue",
         label="max_depth=2", linewidth=2)
plt.plot(X_test, y_2, color="yellowgreen", label="max_depth=5", linewidth=2)
plt.xlabel("data")
plt.ylabel("target")
plt.title("Decision Tree Regression")

plt.legend()
plt.show()

# %%
import pandas as pd
from pandas.plotting import scatter_matrix
df = pd.DataFrame(np.random.randn(1000, 4), columns=['A','B','C','D'])
scatter_matrix(df, alpha=0.2,figsize=(20, 6))
scatter_matrix(df, alpha=0.2,figsize=(20, 6), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000293495B13C8>,
# ...
#       dtype=object)

# %%
y0D = pd.DataFrame({'y': y[:, 0]})
print(y0D)
# Out:
#         y
# 0   100.0
# 1    81.0
# 2    64.0
# 3    49.0
# 4    36.0
# 5    25.0
# 6    16.0
# 7     9.0
# 8     4.0
# 9     1.0
# 10    0.0
# 11    1.0
# 12    4.0
# 13    9.0
# 14   16.0
# 15   25.0
# 16   36.0
# 17   49.0
# 18   64.0
# 19   81.0
